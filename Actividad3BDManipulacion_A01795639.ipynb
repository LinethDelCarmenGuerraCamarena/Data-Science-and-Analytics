# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 3**
# Bases, almacenes y manipulación de datos
#
# ---

# %% [markdown]
# *   NOMBRE: LINETH DEL CARMEN GUERRA CAMARENA
# *   MATRÍCULA: A01795639

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás la base de datos relacional `classicmodels` (MySQL), compuesta por las siguientes tablas:
#
# *   `Customers`: almacena los datos de los clientes.
# *   `Products`: almacena una lista de modelos de coches a escala.
# *   `ProductLines`: almacena una lista de categorías de líneas de productos.
# *   `Orders`: almacena los pedidos de venta realizados por los clientes.
# *   `OrderDetails`: almacena elementos de línea de pedidos de ventas para cada pedido de ventas.
# *   `Payments`: almacena los pagos realizados por los clientes en función de sus cuentas.
# *   `Employees`: almacena toda la información de los empleados, así como la estructura de la organización, como quién informa a quién.
# *   `Offices`: almacena los datos de la oficina de ventas.
#
# Revisa con detalle su esquema para que comprendas cómo se relacionan las tablas anteriores.

# %% [markdown]
# Recuerda que:
#
#
# *   Una **clave primaria** es un atributo (o conjunto) que identifica unívocamente a cada registro en la tabla.
# *   Una **clave foránea** (externa o ajena) es un atributos (o conjunto) en una tabla que es una clave primaria en otra (o posiblemente la misma) tabla.
# *   Las **relaciones** son las líneas que conectan una tabla con otra y el extremo determina la cardinalidad. Las relaciones con línea continua (identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser foránea y primaria (al mismo tiempo) de otra. Las relaciones con línea discontinua (no identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser sólo foránea en otra.

# %% [markdown]
# # **Parte 1**. SQLAlchemy y SQL básico

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 945.8 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0

# %%
import sqlalchemy as sqla
import pymysql
import pandas as pd

# %% [markdown]
# 1.	Crea el motor `sqlalchemy`, con el método `create_engine()` y una conexión con `connect()` como se muestra a continuación:

# %%
# Crear el motor (dialecto://usuarioBD:clave@ipHostDBMS:puerto/esquema
db = sqla.create_engine('mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.157.52:3306/classicmodels', pool_recycle=3600)

# Crea una conexión para luego invocar declaraciones SQL
conn = db.connect()

# %% [markdown]
# Escribe las consultas en SQL para obtener:

# %% [markdown]
# 2.	La información de las líneas de productos.

# %%
query = sqla.text('SELECT * FROM products')
df = pd.read_sql(query, conn)
df
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# 2           1:10   Highway 66 Mini Classics
# 3           1:10          Red Start Diecast
# 4           1:10    Motor City Art Classics
# ..           ...                        ...
# 105        1:700   Carousel DieCast Legends
# 106        1:700  Welly Diecast Productions
# 107        1:700        Second Gear Diecast
# 108         1:72    Motor City Art Classics
# 109         1:72       Unimax Art Galleries
#
#                                     productDescription  quantityInStock  \
# 0    This replica features working kickstand, front...             7933
# 1    Turnable front wheels; steering function; deta...             7305
# 2    Official Moto Guzzi logos and insignias, saddl...             6625
# 3    Model features, official Harley Davidson logos...             5582
# 4    Features include: Turnable front wheels; steer...             3252
# ..                                                 ...              ...
# 105  Completed model measures 19 1/2 inches long, 9...             1956
# 106  Exact replica. Wood and Metal. Many extras inc...             5088
# 107  Polished finish. Exact replia with official lo...             8820
# 108  10" Wingspan with retractable landing gears.Co...             4857
# 109  Measures 38 inches Long x 33 3/4 inches High. ...              414
#
#      buyPrice    MSRP
# 0       48.81   95.70
# 1       98.58  214.30
# 2       68.99  118.94
# 3       91.02  193.66
# 4       85.68  136.00
# ..        ...     ...
# 105     51.09  100.17
# 106     53.63   99.31
# 107     36.27   74.03
# 108     32.77   49.66
# 109     33.30   54.60
#
# [110 rows x 9 columns]

# %% [markdown]
# 3.	Los empleados ordenados por nombre (`firstName`).

# %%
query = sqla.text("SELECT * From employees ORDER BY firstName")
df = pd.read_sql(query, conn)
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1102     Bondur    Gerard     x5408
# 7             1370  Hernandez    Gerard     x2028
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 11            1165   Jennings    Leslie     x3291
# 12            1166   Thompson    Leslie     x4065
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# 18            1612      Marsh     Peter      x102
# 19            1216  Patterson     Steve     x4334
# 20            1619       King       Tom      x103
# 21            1088  Patterson   William     x4871
# 22            1625       Kato   Yoshimi      x102
#
#                               email officeCode  reportsTo  \
# 0      afixter@classicmodelcars.com          6     1088.0
# 1         abow@classicmodelcars.com          1     1056.0
# 2       bjones@classicmodelcars.com          7     1102.0
# 3      dmurphy@classicmodelcars.com          1        NaN
# 4       ftseng@classicmodelcars.com          3     1143.0
# 5      gvanauf@classicmodelcars.com          3     1143.0
# 6      gbondur@classicmodelcars.com          4     1056.0
# 7    ghernande@classicmodelcars.com          4     1102.0
# 8    jfirrelli@classicmodelcars.com          1     1002.0
# 9    jfirrelli@classicmodelcars.com          2     1143.0
# 10       lbott@classicmodelcars.com          7     1102.0
# 11   ljennings@classicmodelcars.com          1     1143.0
# 12   lthompson@classicmodelcars.com          1     1143.0
# 13     lbondur@classicmodelcars.com          4     1102.0
# 14      mnishi@classicmodelcars.com          5     1056.0
# 15     mgerard@classicmodelcars.com          4     1102.0
# 16   mpatterso@classicmodelcars.com          1     1002.0
# 17   pcastillo@classicmodelcars.com          4     1102.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 19  spatterson@classicmodelcars.com          2     1143.0
# 20       tking@classicmodelcars.com          6     1088.0
# 21  wpatterson@classicmodelcars.com          6     1056.0
# 22       ykato@classicmodelcars.com          5     1621.0
#
#                 jobTitle
# 0              Sales Rep
# 1     Sales Manager (NA)
# 2              Sales Rep
# 3              President
# 4              Sales Rep
# 5              Sales Rep
# 6    Sale Manager (EMEA)
# 7              Sales Rep
# 8           VP Marketing
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16              VP Sales
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21  Sales Manager (APAC)
# 22             Sales Rep

# %% [markdown]
# 4.	Los países donde hay oficinas.

# %%
# en este código llamo solo a los países y territorios donde estan las oficinas
# utilize la condicion != su función es omitir en la salida los territorios donde no hay oficinas
query = sqla.text(" SELECT country from offices WHERE territory!='NA'")
df = pd.read_sql(query, conn)
df
# Out:
#      country
# 0     France
# 1      Japan
# 2  Australia
# 3         UK

# %% [markdown]
# 5.	El nombre y teléfono de los clientes de la ciudad de Nueva York (*NYC*).

# %%
query = sqla.text("SELECT customerName, phone FROM customers WHERE city='NYC'")
df = pd.read_sql(query, conn)
df
# Out:
#            customerName       phone
# 0     Land of Toys Inc.  2125557818
# 1    Muscle Machine Inc  2125557413
# 2       Vitachrome Inc.  2125551500
# 3  Classic Legends Inc.  2125558493
# 4       Microscale Inc.  2125551957

# %% [markdown]
# 6.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 1000 unidades en stock.

# %%
query = sqla.text("SELECT productCode, productName, quantityInStock FROM products WHERE quantityInStock <='1000' ")
df = pd.read_sql(query, conn)
df
# Out:
#    productCode                                  productName  quantityInStock
# 0     S12_1099                            1968 Ford Mustang               68
# 1     S18_2248                           1911 Ford Town Car              540
# 2     S18_2581                               P-51-D Mustang              992
# 3     S18_2795                       1928 Mercedes-Benz SSK              548
# 4     S24_2000                     1960 BSA Gold Star DBD34               15
# 5     S32_1374                             1997 BMW F650 ST              178
# 6     S32_3522  1996 Peterbilt 379 Stake Bed with Outrigger              814
# 7     S32_4289                     1928 Ford Phaeton Deluxe              136
# 8     S50_4713                           2002 Yamaha YZR M1              600
# 9    S700_1938                                The Mayflower              737
# 10   S700_3167                           F/A 18 Hornet 1/72              551
# 11    S72_3212                                   Pont Yacht              414

# %% [markdown]
# 7.	Los tres productos más caros, desde el punto de visto de los comercializadores (`buyPrice`).

# %%
query = sqla.text("select * from (select productName,productVendor,buyPrice from products order by buyPrice desc limit 3) products;")
df = pd.read_sql(query, conn)
df
# Out:
#                       productName            productVendor  buyPrice
# 0          1962 LanciaA Delta 16V      Second Gear Diecast    103.42
# 1  1998 Chrysler Plymouth Prowler     Gearbox Collectibles    101.51
# 2        1952 Alpine Renault 1300  Classic Metal Creations     98.58

# %% [markdown]
# 8.	La cantidad de productos por línea de producto (no las existencias en inventario)

# %%
#este código imprimi la cantidad separada de cada producto en línea
query = sqla.text("SELECT productLine, COUNT(productLine) as cantidad FROM products GROUP BY productLine HAVING COUNT(productLine) > 1")
df = pd.read_sql(query, conn)
df
# Out:
#         productLine  cantidad
# 0      Classic Cars        38
# 1       Motorcycles        13
# 2            Planes        12
# 3             Ships         9
# 4            Trains         3
# 5  Trucks and Buses        11
# 6      Vintage Cars        24

# %% [markdown]
# 9.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
#en la siguiente linea hize un inner join para unir la tabla de empleados y oficinas que se unen por la llave foreana officeCode
#realize el conteo de empleados por país y que estuvieran en las misma ubicacion la oficina
#USA es el único país donde me totaliza en tres ubicaciones diferentes debido a la ubicación de la oficina
#utilize un filtro con la condicion where ya que en pasises como Francia y Japaon en la direccion 2 donde especifica la oficina eran nulos en estos dos países
query = sqla.text("SELECT employees.officeCode, COUNT(employees.officeCode) AS cantidad_empleados, offices.country, offices.addressLine1, offices.addressLine2 FROM employees INNER JOIN offices ON employees.officeCode = offices.officeCode where addressLine2 != 'None' GROUP BY employees.officeCode HAVING COUNT(employees.officeCode) > 1")
df = pd.read_sql(query, conn)
df
# Out:
#   officeCode  cantidad_empleados    country           addressLine1  \
# 0          1                   6        USA      100 Market Street
# 1          2                   2        USA       1550 Court Place
# 2          3                   2        USA   523 East 53rd Street
# 3          6                   4  Australia  5-11 Wentworth Avenue
# 4          7                   2         UK    25 Old Broad Street
#
#   addressLine2
# 0    Suite 300
# 1    Suite 102
# 2      apt. 5A
# 3     Floor #2
# 4      Level 7

# %% [markdown]
# 10.	El promedio de los pagos de cada uno de los clientes de España.

# %%
query = sqla.text("SELECT payments.customerNumber,customers.country, customers.customerName , AVG(payments.amount) as promedio_pago from customers INNER JOIN payments ON customers.customerNumber = payments.customerNumber where customers.country='Spain' GROUP BY customers.customerNumber HAVING COUNT(customers.customerNumber) > 1")
db = pd.read_sql(query, conn)
db
# Out:
#    customerNumber country                customerName  promedio_pago
# 0             141   Spain      Euro+ Shopping Channel   55056.844615
# 1             216   Spain          Enaco Distributors   22840.156667
# 2             344   Spain                 CAF Imports   23375.570000
# 3             458   Spain  Corrida Auto Replicas, Ltd   37480.030000
# 4             484   Spain  Iberia Gift Imports, Corp.   25493.925000

# %% [markdown]
# # **Parte 2**. Manipulación de datos con Pandas

# %% [markdown]
# 11.	Carga las tablas empleadas en dataframes con el mismo nombre y resuelve las consultas anteriores con las funciones de Pandas. Cuida no sobreescribir los dataframes originales al resolver las consultas. Debes obtener los mismos resultados que con SQL.

# %%
products = pd.read_sql(sqla.text('SELECT * FROM products'), conn)
customers = pd.read_sql(sqla.text('SELECT * FROM customers'), conn)
employees = pd.read_sql(sqla.text('SELECT * FROM employees'),conn)
productlines = pd.read_sql(sqla.text('SELECT * FROM productlines'), conn)
payments = pd.read_sql(sqla.text('SELECT * FROM payments'), conn)
orders = pd.read_sql(sqla.text('SELECT * FROM orders'), conn)
orderdetails = pd.read_sql(sqla.text('SELECT * FROM orderdetails'),conn)
offices = pd.read_sql(sqla.text('SELECT * FROM offices'), conn)

# %% [markdown]
# 2.Información de las líneas productos

# %%
products
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# 2           1:10   Highway 66 Mini Classics
# 3           1:10          Red Start Diecast
# 4           1:10    Motor City Art Classics
# ..           ...                        ...
# 105        1:700   Carousel DieCast Legends
# 106        1:700  Welly Diecast Productions
# 107        1:700        Second Gear Diecast
# 108         1:72    Motor City Art Classics
# 109         1:72       Unimax Art Galleries
#
#                                     productDescription  quantityInStock  \
# 0    This replica features working kickstand, front...             7933
# 1    Turnable front wheels; steering function; deta...             7305
# 2    Official Moto Guzzi logos and insignias, saddl...             6625
# 3    Model features, official Harley Davidson logos...             5582
# 4    Features include: Turnable front wheels; steer...             3252
# ..                                                 ...              ...
# 105  Completed model measures 19 1/2 inches long, 9...             1956
# 106  Exact replica. Wood and Metal. Many extras inc...             5088
# 107  Polished finish. Exact replia with official lo...             8820
# 108  10" Wingspan with retractable landing gears.Co...             4857
# 109  Measures 38 inches Long x 33 3/4 inches High. ...              414
#
#      buyPrice    MSRP
# 0       48.81   95.70
# 1       98.58  214.30
# 2       68.99  118.94
# 3       91.02  193.66
# 4       85.68  136.00
# ..        ...     ...
# 105     51.09  100.17
# 106     53.63   99.31
# 107     36.27   74.03
# 108     32.77   49.66
# 109     33.30   54.60
#
# [110 rows x 9 columns]

# %% [markdown]
# 3. Los empleados ordenados por (firstName)

# %%
employees.sort_values(by='firstName', ascending=True)[['firstName']]
# Out:
#    firstName
# 17      Andy
# 5    Anthony
# 16     Barry
# 0      Diane
# 10  Foon Yue
# 11    George
# 13    Gerard
# 4     Gerard
# 2       Jeff
# 8      Julie
# 15     Larry
# 6     Leslie
# 7     Leslie
# 12      Loui
# 20      Mami
# 22    Martin
# 1       Mary
# 14    Pamela
# 18     Peter
# 9      Steve
# 19       Tom
# 3    William
# 21   Yoshimi

# %% [markdown]
# 4. Los países donde hay oficinas

# %%
offices[offices['territory'] != 'NA'][['country']]
# Out:
#      country
# 3     France
# 4      Japan
# 5  Australia
# 6         UK

# %% [markdown]
# 5. El nombre y teléfono de los clientes de la ciudad de Nueva York (NYC).

# %%
customers[customers['city'] == 'NYC'][['customerName','phone']]
# Out:
#              customerName       phone
# 9       Land of Toys Inc.  2125557818
# 15     Muscle Machine Inc  2125557413
# 27        Vitachrome Inc.  2125551500
# 98   Classic Legends Inc.  2125558493
# 105       Microscale Inc.  2125551957

# %% [markdown]
# 6.El código y nombre de los productos del vendedor Gearbox Collectibles que tengan menos de 1000 unidades en stock.

# %%
#query = sqla.text("SELECT productCode, productName, quantityInStock FROM products WHERE quantityInStock <='1000' ")
products[products['quantityInStock'] <=1000][['productCode','productName','quantityInStock']]
# Out:
#     productCode                                  productName  quantityInStock
# 6      S12_1099                            1968 Ford Mustang               68
# 26     S18_2248                           1911 Ford Town Car              540
# 30     S18_2581                               P-51-D Mustang              992
# 32     S18_2795                       1928 Mercedes-Benz SSK              548
# 61     S24_2000                     1960 BSA Gold Star DBD34               15
# 85     S32_1374                             1997 BMW F650 ST              178
# 89     S32_3522  1996 Peterbilt 379 Stake Bed with Outrigger              814
# 90     S32_4289                     1928 Ford Phaeton Deluxe              136
# 95     S50_4713                           2002 Yamaha YZR M1              600
# 98    S700_1938                                The Mayflower              737
# 104   S700_3167                           F/A 18 Hornet 1/72              551
# 109    S72_3212                                   Pont Yacht              414

# %% [markdown]
# 7.Los tres productos más caros, desde el punto de visto de los comercializadores (buyPrice).

# %%
products.sort_values(by='buyPrice', ascending=False)[['productName','productVendor','buyPrice']][:3]
# Out:
#                        productName            productVendor  buyPrice
# 5           1962 LanciaA Delta 16V      Second Gear Diecast    103.42
# 25  1998 Chrysler Plymouth Prowler     Gearbox Collectibles    101.51
# 1         1952 Alpine Renault 1300  Classic Metal Creations     98.58

# %% [markdown]
# 8. La cantidad de productos por línea de producto (no las existencias en inventario

# %%
p = products.value_counts('productLine')
print(p)
# Out:
# productLine
# Classic Cars        38
# Vintage Cars        24
# Motorcycles         13
# Planes              12
# Trucks and Buses    11
# Ships                9
# Trains               3
# dtype: int64

# %% [markdown]
# 9.La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
# en la ultima columna visualizamos la cantidad de empleado por país tomando en consideración la ubicación de la oficina
cantidad= pd.merge(employees,offices, on='officeCode')
cantidad[['addressLine1','addressLine2','country']].value_counts()
# Out:
# addressLine1           addressLine2  country
# 100 Market Street      Suite 300     USA          6
# 5-11 Wentworth Avenue  Floor #2      Australia    4
# 1550 Court Place       Suite 102     USA          2
# 25 Old Broad Street    Level 7       UK           2
# 523 East 53rd Street   apt. 5A       USA          2
# dtype: int64

# %% [markdown]
# 10.El promedio de los pagos de cada uno de los clientes de España.

# %%
#ver los codigos de los clientes en España y omitimos los NaN
cliente = customers[customers['country'] == 'Spain'][['country','customerName','customerNumber']]
cliente
# Out:
#     country                customerName  customerNumber
# 10    Spain      Euro+ Shopping Channel             141
# 39    Spain          Enaco Distributors             216
# 44    Spain               ANG Resellers             237
# 76    Spain                 CAF Imports             344
# 106   Spain  Corrida Auto Replicas, Ltd             458
# 109   Spain         Anton Designs, Ltd.             465
# 116   Spain  Iberia Gift Imports, Corp.             484

# %%
#Eliminamos los dos clientes que no tienen ingresos
cliente.drop([44,109])
# Out:
#     country                customerName  customerNumber
# 10    Spain      Euro+ Shopping Channel             141
# 39    Spain          Enaco Distributors             216
# 76    Spain                 CAF Imports             344
# 106   Spain  Corrida Auto Replicas, Ltd             458
# 116   Spain  Iberia Gift Imports, Corp.             484

# %%
#calculando el promedio de pagos de cada cliente en España segun el numero de cliente
cliente1 = payments[(payments['customerNumber'] == 141)][['amount']].mean()
cliente2 = payments[(payments['customerNumber'] == 216)][['amount']].mean()
cliente3 = payments[(payments['customerNumber'] == 344)][['amount']].mean()
cliente4 = payments[(payments['customerNumber'] == 458)][['amount']].mean()
cliente5 = payments[(payments['customerNumber'] == 484)][['amount']].mean()

# %%
print(cliente1,cliente2,cliente3,cliente4,cliente5)
# Out:
# amount    55056.844615
# dtype: float64 amount    22840.156667
# dtype: float64 amount    23375.57
# dtype: float64 amount    37480.03
# dtype: float64 amount    25493.925
# dtype: float64

# %% [markdown]
# # **Parte 3**. Cliente de Python Firestore

# %% [markdown]
# En esta fase te conectarás a una base de datos no relacional de Firestore desde Python. Para ello utilizarás los módulos `credentials` y `firestore` de la biblioteca `firebase_admin`.

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %% [markdown]
# El archivo `veterinary.json` almacena la clave privada para autenticar una cuenta y autorizar el acceso a los servicios de Firebase. A través de la función `Certificate()`, se regresa una credencial inicializada, que puedes utilizar para crear una nueva instancia de la aplicación. Después de eso, tu conexión a Firestore utilizará las reglas de seguridad establecidas para la base de datos y el usuario autenticado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
DIR = "/content/drive/MyDrive/data science"
os.chdir(DIR)

# %%
cred = credentials.Certificate('veterinary.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %% [markdown]
# 12.	Investiga cómo leer la colección `PET_OWNER` y mostrar su contenido en un dataframe. Asegúrate de incluir el id en el resultado

# %%
docs = db.collection("PET_OWNER").get()

for doc in docs:
  dataframe = (f"{doc.id} => {doc.to_dict()}")
  print(dataframe)
# Out:
# 0D6yFSs2eu4nYwf2dnQ0 => {'ownerLastName': 'Taylor', 'ownerFirstName': 'Sam', 'phone': '555-454-3465', 'email': None}
# 98357ufgjmWUxjnAuzbz => {'phone': None, 'ownerFirstName': 'Miles', 'email': 'miles.trent@somewhere.com', 'ownerLastName': 'Trent'}
# AFtZincSZxjC4Mcxf9Pf => {'ownerLastName': 'Frier', 'ownerFirstName': 'Liz', 'phone': '555-537-6543', 'email': 'liz.frier@somewhere.com'}
# GYDixDwHjMyihjL8TmsM => {'ownerLastName': 'Mayberry', 'phone': '555-454-1243', 'email': None, 'ownerFirstName': 'Jenny'}
# IpxTuB6FILhwQFcspLws => {'email': "'marcha.downs@somewhere.com", 'phone': '555-537-8765', 'ownerFirstName': 'Marsha', 'ownerLastName': 'Downs'}
# QoXBfS1JdRp6BqgLzaAz => {'ownerFirstName': 'Ken', 'phone': '555-454-2354', 'email': None, 'ownerLastName': 'Roberts'}
# TTHPxJUVtduW4DXCcs8J => {'key': 'value'}
# eUtZ44lPRbSHXX04EDp7 => {'email': 'nigel.melnik@somewhere.com', 'ownerLastName': 'Melnik', 'ownerFirstName': 'Nigel', 'phone': '555-232-5678'}
# n2GG9rlfGOmE0P4TcU0T => {'ownerLastName': 'James', 'ownerFirstName': 'Richard', 'email': 'richard.james@somewhere.com', 'phone': '555-537-7654'}
# pDlJlul8EJXO8FBJvFkN => {'ownerFirstName': 'Jim', 'ownerLastName': 'Rogers', 'phone': '555-232-3456', 'email': 'jim.rogers@somewhere.com'}
# tAlJ74xQ7tT4TUHwZgmH => {'phone': '555-232-4567', 'ownerLastName': 'Keenan', 'ownerFirstName': 'Mary', 'email': 'mary.keenan@somewhere.com'}
# veterinary.json => {'universe_domain': 'googleapis.com', 'auth_uri': 'https://accounts.google.com/o/oauth2/auth', 'client_id': '116291176305839996310', 'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/firebase-adminsdk-ik0th%40veterinary-3bc04.iam.gserviceaccount.com', 'client_email': 'firebase-adminsdk-ik0th@veterinary-3bc04.iam.gserviceaccount.com', 'project_id': 'veterinary-3bc04', 'private_key_id': '5c1f8760a6b2453baee6170eb87cac4f60943bfa', 'type': 'service_account', 'private_key': '-----BEGIN PRIVATE KEY-----\\nO61fijKwQSqZ3cGTWycIssR1\n-----END PRIVATE KEY-----\n', 'token_uri': 'https://oauth2.googleapis.com/token', 'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs'}
# x8vGPfIluLqcDIiXHKaj => {'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs', 'project_id': 'veterinary-3bc04', 'auth_uri': 'https://accounts.google.com/o/oauth2/auth', 'client_email': 'firebase-adminsdk-ik0th@veterinary-3bc04.iam.gserviceaccount.com', 'private_key': '-----BEGIN PRIVATE KEY-----\\nO61fijKwQSqZ3cGTWycIssR1\n-----END PRIVATE KEY-----\n', 'universe_domain': 'googleapis.com', 'client_id': '116291176305839996310', 'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/firebase-adminsdk-ik0th%40veterinary-3bc04.iam.gserviceaccount.com', 'type': 'service_account', 'private_key_id': '5c1f8760a6b2453baee6170eb87cac4f60943bfa', 'token_uri': 'https://oauth2.googleapis.com/token'}

# %%
firebase_admin.delete_app(firebase_admin.get_app())
